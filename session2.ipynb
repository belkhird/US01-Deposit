# %%
import pandas as pd

# %%
pd.read_excel('Data-sheet-STUDENTS.xlsx')
# Out:
#    Unnamed: 0                         Indicator #                Unnamed: 2  \
# 0   Country #                       Source link:                        NaN
# 1         NaN      Country (according to CN Gov):  Date of research inquiry
# 2           1                         Afghanistan                       NaN
# 3           2                             Albania                       NaN
# 4           3                             Armenia                       NaN
# 5           4                          Azerbaijan                       NaN
# 6           5                             Bahrain                       NaN
# 7           6                          Bangladesh                       NaN
# 8           7                             Belarus                       NaN
# 9           8                              Bhutan                       NaN
# 10          9              Bosnia and Herzegovina                       NaN
# ...

# %%
myfile=pd.read_excel('Data-sheet-STUDENTS.xlsx', header=2, index_col=0)

# %%
myfile['Country (according to CN Gov):'][1]
# Out:
# 'Afghanistan'

# %%
myfile
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# 6                           Bangladesh                      NaT
# 7                              Belarus                      NaT
# 8                               Bhutan                      NaT
# 9               Bosnia and Herzegovina                      NaT
# 10                              Brunei                      NaT
# 11                            Bulgaria                      NaT
# 12                            Cambodia               2018-08-16
# 13                               China                      NaT
# 14                             Croatia                      NaT
# ...

# %%
print(myfile['Country (according to CN Gov):'])
# Out:
# 1                            Afghanistan
# 2                                Albania
# 3                                Armenia
# 4                             Azerbaijan
# 5                                Bahrain
# 6                             Bangladesh
# 7                                Belarus
# 8                                 Bhutan
# 9                 Bosnia and Herzegovina
# 10                                Brunei
# 11                              Bulgaria
# 12                              Cambodia
# 13                                 China
# 14                               Croatia
# 15                        Czech Republic
# 16                            East Timor
# 17                                 Egypt
# 18                               Estonia
# 19                      France (Not BRI)
# 20                               Georgia
# 21                     Germany (not BRI)
# 22                               Hungary
# 23                                 India
# ...

# %%
for i in myfile.index:
    print(myfile['Country (according to CN Gov):'][i])
    
    #print
# Out:
# Afghanistan
# Albania
# Armenia
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Bhutan
# Bosnia and Herzegovina
# Brunei
# Bulgaria
# Cambodia
# China
# Croatia
# Czech Republic
# East Timor
# Egypt
# Estonia
# France (Not BRI)
# Georgia
# Germany (not BRI)
# Hungary
# India
# Indonesia
# Iran
# Iraq
# Israel
# Jordan
# Kazakhstan
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lithuania
# Macedonia
# Malaysia
# Maldives
# Moldova
# Mongolia
# Montenegro
# Myanmar
# Nepal
# Oman
# Pakistan
# Philippines
# Poland
# Qatar
# Romania
# Russia
# Saudi Arabia
# Serbia
# Singapore
# Slovakia
# Slovenia
# Sri Lanka
# Syria
# Tajikistan
# Thailiand
# The United Arab Emirates
# Turkey
# Turkmenistan
# United Kingdom (Not BRI)
# United States of America (Not BRI)
# Ukraine
# Uzbekistan
# Vietnam
# Yemen

# %% [markdown]
# si on met break il va venir faire les pays un par un

# %%
import requests

# %%
r = requests.get('https://restcountries.eu/rest/v2/name/Afghanistan')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'name': 'Afghanistan',
#   'topLevelDomain': ['.af'],
#   'alpha2Code': 'AF',
#   'alpha3Code': 'AFG',
#   'callingCodes': ['93'],
#   'capital': 'Kabul',
#   'altSpellings': ['AF', 'Afġānistān'],
#   'region': 'Asia',
#   'subregion': 'Southern Asia',
#   'population': 27657145,
#   'latlng': [33.0, 65.0],
#   'demonym': 'Afghan',
#   'area': 652230.0,
#   'gini': 27.8,
#   'timezones': ['UTC+04:30'],
#   'borders': ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN'],
#   'nativeName': 'افغانستان',
#   'numericCode': '004',
#   'currencies': [{'code': 'AFN', 'name': 'Afghan afghani', 'symbol': '؋'}],
#   'languages': [{'iso639_1': 'ps',
#     'iso639_2': 'pus',
#     'name': 'Pashto',
#     'nativeName': 'پښتو'},
#    {'iso639_1': 'uz',
#     'iso639_2': 'uzb',
#     'name': 'Uzbek',
#     'nativeName': 'Oʻzbek'},
#    {'iso639_1': 'tk',
#     'iso639_2': 'tuk',
#     'name': 'Turkmen',
#     'nativeName': 'Türkmen'}],
#   'translations': {'de': 'Afghanistan',
#    'es': 'Afganistán',
# ...

# %%
r.json()[0]
# Out:
# {'name': 'Afghanistan',
#  'topLevelDomain': ['.af'],
#  'alpha2Code': 'AF',
#  'alpha3Code': 'AFG',
#  'callingCodes': ['93'],
#  'capital': 'Kabul',
#  'altSpellings': ['AF', 'Afġānistān'],
#  'region': 'Asia',
#  'subregion': 'Southern Asia',
#  'population': 27657145,
#  'latlng': [33.0, 65.0],
#  'demonym': 'Afghan',
#  'area': 652230.0,
#  'gini': 27.8,
#  'timezones': ['UTC+04:30'],
#  'borders': ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN'],
#  'nativeName': 'افغانستان',
#  'numericCode': '004',
#  'currencies': [{'code': 'AFN', 'name': 'Afghan afghani', 'symbol': '؋'}],
#  'languages': [{'iso639_1': 'ps',
#    'iso639_2': 'pus',
#    'name': 'Pashto',
#    'nativeName': 'پښتو'},
#   {'iso639_1': 'uz',
#    'iso639_2': 'uzb',
#    'name': 'Uzbek',
#    'nativeName': 'Oʻzbek'},
#   {'iso639_1': 'tk',
#    'iso639_2': 'tuk',
#    'name': 'Turkmen',
#    'nativeName': 'Türkmen'}],
#  'translations': {'de': 'Afghanistan',
#   'es': 'Afganistán',
#   'fr': 'Afghanistan',
# ...

# %% [markdown]
# ca nous affiche un tableau pour lui dire qu'on veut que la première ligne du tableau je mets [0]

# %%
r.json()[0]['alpha3Code']
# Out:
# 'AFG'

# %% [markdown]
# ici je lui demande une colonne en particulier de la première ligne de mon tableau

# %%
iso_codes={}

# %% [markdown]
# iso_codes est une variables et a chaque fois qu'on va executer le bloc ca va mettre la variable à 0 chose que nous voulons pas forcement donc on va slit cell pour éviter de la remettre à 0 à chaque exécution

# %%
for index, name in myfile['Country (according to CN Gov):'].items():
    if name in iso_codes:
        continue
        
    cleaned_name=name.split('(')[0].strip()
    if cleaned_name == 'Thailiand':
        cleaned_name='Thailand'
        
    if cleaned_name == 'The United Arab Emirates':
        cleaned_name='United Arab Emirates'
        
    url= 'https://restcountries.eu/rest/v2/name/'+cleaned_name
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        country_code=data[0]['alpha3Code']
        iso_codes[name]=country_code
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)

# %%
iso_codes
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Armenia': 'ARM',
#  'Azerbaijan': 'AZE',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Belarus': 'BLR',
#  'Bhutan': 'BTN',
#  'Bosnia and Herzegovina': 'BIH',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Cambodia': 'KHM',
#  'China': 'CHN',
#  'Croatia': 'HRV',
#  'Czech Republic': 'CZE',
#  'East Timor': 'TLS',
#  'Egypt': 'EGY',
#  'Estonia': 'EST',
#  'France (Not BRI)': 'FRA',
#  'Georgia': 'GEO',
#  'Germany (not BRI)': 'DEU',
#  'Hungary': 'HUN',
#  'India': 'IOT',
#  'Indonesia': 'IDN',
#  'Iran': 'IRN',
#  'Iraq': 'IRQ',
#  'Israel': 'ISR',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  'Laos': 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lithuania': 'LTU',
#  'Macedonia': 'MKD',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Moldova': 'MDA',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Myanmar': 'MMR',
#  'Nepal': 'NPL',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
# ...

# %% [markdown]
# contiue veut dire revenir à la boucle for, terminer la boucle en cours et aller au i+1

# %%
myfile ['isocode']=myfile ['Country (according to CN Gov):'].apply(lambda x: iso_codes[x])

# %%
myfile['isocode']
# Out:
# 1     AFG
# 2     ALB
# 3     ARM
# 4     AZE
# 5     BHR
# 6     BGD
# 7     BLR
# 8     BTN
# 9     BIH
# 10    BRN
# 11    BGR
# 12    KHM
# 13    CHN
# 14    HRV
# 15    CZE
# 16    TLS
# 17    EGY
# 18    EST
# 19    FRA
# 20    GEO
# 21    DEU
# 22    HUN
# 23    IOT
# 24    IDN
# 25    IRN
# 26    IRQ
# 27    ISR
# 28    JOR
# 29    KAZ
# 30    KWT
#      ...
# 39    MDA
# 40    MNG
# 41    MNE
# 42    MMR
# 43    NPL
# 44    OMN
# 45    PAK
# 46    PHL
# 47    POL
# 48    QAT
# 49    ROU
# 50    RUS
# 51    SAU
# 52    SRB
# 53    SGP
# 54    SVK
# 55    SVN
# 56    LKA
# 57    SYR
# 58    TJK
# 59    THA
# 60    ARE
# 61    TUR
# 62    TKM
# 63    GBR
# 64    USA
# 65    UKR
# 66    UZB
# 67    VNM
# 68    YEM
# Name: isocode, Length: 68, dtype: object

# %% [markdown]
# ici on va créer une nouvelle colonne pour mettre les isocodes récupérés grâce à l'API

# %%
myfile[['isocode','Country (according to CN Gov):']]
# Out:
#    isocode      Country (according to CN Gov):
# 1      AFG                         Afghanistan
# 2      ALB                             Albania
# 3      ARM                             Armenia
# 4      AZE                          Azerbaijan
# 5      BHR                             Bahrain
# 6      BGD                          Bangladesh
# 7      BLR                             Belarus
# 8      BTN                              Bhutan
# 9      BIH              Bosnia and Herzegovina
# 10     BRN                              Brunei
# 11     BGR                            Bulgaria
# 12     KHM                            Cambodia
# 13     CHN                               China
# 14     HRV                             Croatia
# 15     CZE                      Czech Republic
# 16     TLS                          East Timor
# 17     EGY                               Egypt
# 18     EST                             Estonia
# 19     FRA                    France (Not BRI)
# ...

# %% [markdown]
# ici je demande à afficher deux colonnes particulières de mon tableau

# %%
r = requests.get('http://api.worldbank.org/v2/country/chn/indicator/GC.TAX.IMPT.ZS?format=json')

# %%
  r.status_code
# Out:
# 200

# %%
r.json()[1][2]['value']

# %%
valeurs={}

# %%
    import time

# %%
for index, name in myfile['isocode'].items():
    print(name)
    
    if name in valeurs:
        continue
         
    time.sleep(5)
    
    if name == 'IOT':
        url= 'http://api.worldbank.org/v2/country/' + 'IND' + '/indicator/GC.TAX.IMPT.ZS?format=json' 
    else:
        url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/GC.TAX.IMPT.ZS?format=json'
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        compteur=0
        
        if name == 'BRN' or name == 'LAO'or name == 'MNE'or name == 'OMN' or name == 'PAK' or name == 'QAT' or name == 'SYR' or name == 'TKM' or name == 'VNM' or name == 'YEM':
            valeurs[name]="No value"
        else:
            valeurs[name]=data[1][compteur]['value']
        
        while valeurs[name] is None:
            compteur += 1
            valeurs[name]=data[1][compteur]['value']
            
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY
# EST
# FRA
# GEO
# DEU
# HUN
# IOT
# IDN
# IRN
# IRQ
# ISR
# JOR
# KAZ
# KWT
# KGZ
# LAO
# LVA
# LBN
# LTU
# MKD
# MYS
# MDV
# MDA
# MNG
# MNE
# MMR
# NPL
# OMN
# PAK
# PHL
# POL
# QAT
# ROU
# RUS
# SAU
# SRB
# SGP
# SVK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-91ee6109ff78> in <module>
#      11     else:
#      12         url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/GC.TAX.IMPT.ZS?format=json'
# ---> 13     r= requests.get(url)
#      14     if r.status_code==200:
#      15         data= r.json()
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
# ...

# %%
valeurs

# %%
myfile ['IMF WB\nCustoms and other import duties (% of tax revenue) 2016']=myfile ['isocode'].apply(lambda x: valeurs[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-db70c3013cb6> in <module>
# ----> 1 myfile ['IMF WB\nCustoms and other import duties (% of tax revenue) 2016']=myfile ['isocode'].apply(lambda x: valeurs[x])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-108-db70c3013cb6> in <lambda>(x)
# ----> 1 myfile ['IMF WB\nCustoms and other import duties (% of tax revenue) 2016']=myfile ['isocode'].apply(lambda x: valeurs[x])
#
# NameError: name 'valeurs' is not defined

# %%
myfile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-db00b2897b10> in <module>
# ----> 1 myfile
#
# NameError: name 'myfile' is not defined

# %%
# Out:
# {'AFG': 35.203141190445}

# %%
valeurs1={}

# %%
for index, name in myfile['isocode'].items():
    print(name)
    
    if name in valeurs1:
        continue
         
    time.sleep(5)
    
    if name == 'IOT':
        url= 'http://api.worldbank.org/v2/country/' + 'IND' + '/indicator/FB.AST.NPER.ZS?format=json' 
    else:
        url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/FB.AST.NPER.ZS?format=json'
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        compteur=0
        
        if name == 'AZE'or name == 'BHR'or name == 'TLS' or name == 'EGY' or name == 'IRN' or name == 'IRQ' or name == 'JOR' or name == 'LAO' or name == 'MNG' or name == 'MNE' or name == 'MMR' or name == 'OMN' or name == 'QAT' or name == 'SRB' or name == 'SYR' or name == 'TKM' or name == 'YEM' :
            valeurs1[name]='No value'
        else:
            valeurs1[name]=data[1][compteur]['value']
        while valeurs1[name] is None:
            compteur += 1
            valeurs1[name]=data[1][compteur]['value']
    
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY
# EST
# FRA
# GEO
# DEU
# HUN
# IOT
# IDN
# IRN
# IRQ
# ISR
# JOR
# KAZ
# KWT
# KGZ
# LAO
# LVA
# LBN
# LTU
# MKD
# MYS
# MDV
# MDA
# MNG
# MNE
# MMR
# NPL
# OMN
# PAK
# PHL
# POL
# QAT
# ROU
# RUS
# SAU
# SRB
# SGP
# SVK
# SVN
# LKA
# SYR
# TJK
# THA
# ARE
# TUR
# TKM
# GBR
# USA
# UKR
# UZB
# VNM
# YEM

# %%
valeurs1
# Out:
# {'AFG': 12.2018301907814,
#  'ALB': 13.2325333809177,
#  'ARM': 5.43231777940314,
#  'AZE': None,
#  'BHR': 'No value',
#  'BGD': 8.39790781352825,
#  'BLR': 12.8521944714263,
#  'BTN': 8.41730841915147,
#  'BIH': 10.0462751524632,
#  'BRN': 3.53839872754278,
#  'BGR': 10.434453416252,
#  'KHM': 2.07247749965176,
#  'CHN': 1.74435460635256,
#  'HRV': 11.2015418446349,
#  'CZE': 3.74172036339308,
#  'TLS': None,
#  'EGY': None,
#  'EST': 0.698391485843613,
#  'FRA': 3.08041478456105,
#  'GEO': 2.77879996979284,
#  'DEU': 1.5,
#  'HUN': 4.16591962701521,
#  'IOT': 9.98,
#  'IDN': 2.55700481762471,
#  'IRN': None,
#  'IRQ': None,
#  'ISR': 1.29066005069854,
#  'JOR': None,
#  'KAZ': 9.30976808361683,
#  'KWT': 1.94939026221767,
#  'KGZ': 7.36791636375828,
#  'LAO': None,
#  'LVA': 5.50697759974228,
#  'LBN': 5.66619171650023,
#  'LTU': 3.17709584415856,
#  'MKD': 6.09844460015566,
#  'MYS': 1.54531081879587,
#  'MDV': 10.45472871593,
#  'MDA': 18.377209388791,
#  'MNG': 'No value',
# ...

# %%
myfile ['WB IMF Non-performing loans to total gross loans ratio (%)']=myfile ['isocode'].apply(lambda x: valeurs1[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-b4df958c4f55> in <module>
# ----> 1 myfile ['WB IMF Non-performing loans to total gross loans ratio (%)']=myfile ['isocode'].apply(lambda x: valeurs1[x])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-103-b4df958c4f55> in <lambda>(x)
# ----> 1 myfile ['WB IMF Non-performing loans to total gross loans ratio (%)']=myfile ['isocode'].apply(lambda x: valeurs1[x])
#
# NameError: name 'valeurs1' is not defined

# %%
myfile
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# 6                           Bangladesh                      NaT
# 7                              Belarus                      NaT
# 8                               Bhutan                      NaT
# 9               Bosnia and Herzegovina                      NaT
# 10                              Brunei                      NaT
# 11                            Bulgaria                      NaT
# 12                            Cambodia               2018-08-16
# 13                               China                      NaT
# 14                             Croatia                      NaT
# ...

# %%
valeurs2={}

# %%
for index, name in myfile['isocode'].items():
    print(name)
    
    if name in valeurs2:
        continue
         
    time.sleep(5)
    
    if name == 'IOT':
        url= 'http://api.worldbank.org/v2/country/' + 'IND' + '/indicator/IS.RRS.GOOD.MT.K6?format=json' 
    else:
        url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/IS.RRS.GOOD.MT.K6?format=json'
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        compteur=0
        
        if name == 'AFG' or name == 'BHR' or name == 'BTN' or name == 'BRN' or name == 'TLS' or name == 'KWT' or name == 'LAO' or name == 'LBN' or name == 'MDV' or name == 'MNE' or name == 'NPL' or name == 'OMN' or name == 'QAT' or name == 'SGP' or name == 'ARE' or name == 'YEM': 
            valeurs2[name]='No value'
        else:
            valeurs2[name]=data[1][compteur]['value']
        while valeurs2[name] is None:
            compteur += 1
            valeurs2[name]=data[1][compteur]['value']
    
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY
# EST
# FRA
# GEO
# DEU
# HUN
# IOT
# IDN
# IRN
# IRQ
# ISR
# JOR
# KAZ
# KWT
# KGZ
# LAO
# LVA
# LBN
# LTU
# MKD
# MYS
# MDV
# MDA
# MNG
# MNE
# MMR
# NPL
# OMN
# PAK
# PHL
# POL
# QAT
# ROU
# RUS
# SAU
# SRB
# SGP
# SVK
# SVN
# LKA
# SYR
# TJK
# THA
# ARE
# TUR
# TKM
# GBR
# USA
# UKR
# UZB
# VNM
# YEM

# %%
valeurs2
# Out:
# {'AFG': None,
#  'ALB': 46,
#  'ARM': 689.46,
#  'AZE': 4633,
#  'BHR': None,
#  'BGD': 710,
#  'BLR': 48538,
#  'BTN': None,
#  'BIH': 1114.326546,
#  'BRN': None,
#  'BGR': 2859.82,
#  'KHM': 92,
#  'CHN': 2146466,
#  'HRV': 2012,
#  'CZE': 11819,
#  'TLS': None,
#  'EGY': 1592.136,
#  'EST': 4807,
#  'FRA': 24598,
#  'GEO': 2963,
#  'DEU': 70614,
#  'HUN': 446.842,
#  'IOT': 620175,
#  'IDN': 7166,
#  'IRN': 30299,
#  'IRQ': 249.463,
#  'ISR': 1404.378038,
#  'JOR': 344.1,
#  'KAZ': 206258,
#  'KWT': None,
#  'KGZ': 935,
#  'LAO': None,
#  'LVA': 9971,
#  'LBN': None,
#  'LTU': 15414,
#  'MKD': 276.627,
#  'MYS': 1234,
#  'MDV': None,
#  'MDA': 971,
#  'MNG': 13493,
#  'MNE': 'No value',
#  'MMR': 885,
#  'NPL': None,
#  'OMN': None,
#  'PAK': 5031,
#  'PHL': 0.764,
#  'POL': 28720,
#  'QAT': None,
#  'ROU': 8563,
#  'RUS': 2491875.9,
#  'SAU': 1852.472,
#  'SRB': 3287.8,
#  'SGP': None,
#  'SVK': 7008.4,
#  'SVN': 4447.41,
#  'LKA': 127.39,
#  'SYR': 2206.297,
#  'TJK': 165,
# ...

# %%
myfile ['UIC Rail freight (mn ton x km travelled)']=myfile ['isocode'].apply(lambda x: valeurs2[x])

# %%
myfile
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# 6                           Bangladesh                      NaT
# 7                              Belarus                      NaT
# 8                               Bhutan                      NaT
# 9               Bosnia and Herzegovina                      NaT
# 10                              Brunei                      NaT
# 11                            Bulgaria                      NaT
# 12                            Cambodia               2018-08-16
# 13                               China                      NaT
# 14                             Croatia                      NaT
# ...

# %%
myfile= pd.read_pickle('ind_tab')

# %%
myfile
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# 6                           Bangladesh                      NaT
# 7                              Belarus                      NaT
# 8                               Bhutan                      NaT
# 9               Bosnia and Herzegovina                      NaT
# 10                              Brunei                      NaT
# 11                            Bulgaria                      NaT
# 12                            Cambodia               2018-08-16
# 13                               China                      NaT
# 14                             Croatia                      NaT
# ...

# %%
myfile ['UIC Rail freight (mn ton x km travelled)']
# Out:
# 1            None
# 2              46
# 3          689.46
# 4            4633
# 5            None
# 6             710
# 7           48538
# 8            None
# 9         1114.33
# 10           None
# 11        2859.82
# 12             92
# 13        2146466
# 14           2012
# 15          11819
# 16           None
# 17        1592.14
# 18           4807
# 19          24598
# 20           2963
# 21          70614
# 22        446.842
# 23         620175
# 24           7166
# 25          30299
# 26        249.463
# 27        1404.38
# 28          344.1
# 29         206258
# 30           None
#          ...
# 39            971
# 40          13493
# 41       No value
# 42            885
# 43           None
# 44           None
# 45           5031
# 46          0.764
# 47          28720
# 48           None
# 49           8563
# 50    2.49188e+06
# 51        1852.47
# 52         3287.8
# 53           None
# 54         7008.4
# 55        4447.41
# 56         127.39
# 57         2206.3
# ...

# %%
valeurs3={}

# %%
for index, name in myfile['isocode'].items():
    print(name)
    
    if name in valeurs3:
        continue
         
    time.sleep(5)
    
    if name == 'IOT':
        url= 'http://api.worldbank.org/v2/country/' + 'IND' + '/indicator/IS.AIR.GOOD.MT.K1?format=json' 
    else:
        url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/IS.AIR.GOOD.MT.K1?format=json'
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        compteur=0
        
        if name == 'YEM':
            valeurs3[name]='No value'
        else:
            valeurs3[name]=data[1][compteur]['value']
        while valeurs3[name] is None:
            compteur += 1
            valeurs3[name]=data[1][compteur]['value']
    
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY
# EST
# FRA
# GEO
# DEU
# HUN
# IOT
# IDN
# IRN
# IRQ
# ISR
# JOR
# KAZ
# KWT
# KGZ
# LAO
# LVA
# LBN
# LTU
# MKD
# MYS
# MDV
# MDA
# MNG
# MNE
# MMR
# NPL
# OMN
# PAK
# PHL
# POL
# QAT
# ROU
# RUS
# SAU
# SRB
# SGP
# SVK
# SVN
# LKA
# SYR
# TJK
# THA
# ARE
# TUR
# TKM
# GBR
# USA
# UKR
# UZB
# VNM
# YEM

# %%
valeurs3
# Out:
# {'AFG': 'No value',
#  'ALB': 46,
#  'ARM': 689.46,
#  'AZE': 4633,
#  'BHR': None,
#  'BGD': 63.8181519848784,
#  'BLR': 1.9004,
#  'BTN': 0.690916,
#  'BIH': 8.7e-05,
#  'BRN': 129.352,
#  'BGR': 1.37521,
#  'KHM': 0.67645,
#  'CHN': 25256.2071,
#  'HRV': 0.52979,
#  'CZE': 25.22637,
#  'TLS': None,
#  'EGY': 437.625328,
#  'EST': 0.003,
#  'FRA': 4443.789,
#  'GEO': 0.7509,
#  'DEU': 7969.86364,
#  'HUN': 0,
#  'IOT': 2703.96417383,
#  'IDN': 1131.913455454,
#  'IRN': 290.737968069473,
#  'IRQ': 16.199317,
#  'ISR': 994.542,
#  'JOR': 175.8386,
#  'KAZ': 50.217906,
#  'KWT': 392.363053,
#  'KGZ': 0.02165,
#  'LAO': 1.53255252911646,
#  'LVA': 4.01487,
#  'LBN': 56.569,
#  'LTU': 0.472,
#  'MKD': 0,
#  'MYS': 1404.40777752105,
#  'MDV': 7.745645613,
#  'MDA': 0.6445,
#  'MNG': 7.819001,
#  'MNE': 0.1345,
#  'MMR': 4.74215983168867,
#  'NPL': 4.655766324,
#  'OMN': 510.425983,
#  'PAK': 217.534134,
#  'PHL': 835.904513,
#  'POL': 271.488,
#  'QAT': 12666.7094,
#  'ROU': 2.71,
# ...

# %%
myfile ['ICAO air freight (mn ton x km travelled)']=myfile ['isocode'].apply(lambda x: valeurs3[x])

# %%
myfile ['ICAO air freight (mn ton x km travelled)']
# Out:
# 1      No value
# 2            46
# 3        689.46
# 4          4633
# 5          None
# 6       63.8182
# 7        1.9004
# 8      0.690916
# 9       8.7e-05
# 10      129.352
# 11      1.37521
# 12      0.67645
# 13      25256.2
# 14      0.52979
# 15      25.2264
# 16         None
# 17      437.625
# 18        0.003
# 19      4443.79
# 20       0.7509
# 21      7969.86
# 22            0
# 23      2703.96
# 24      1131.91
# 25      290.738
# 26      16.1993
# 27      994.542
# 28      175.839
# 29      50.2179
# 30      392.363
#         ...
# 39       0.6445
# 40        7.819
# 41       0.1345
# 42      4.74216
# 43      4.65577
# 44      510.426
# 45      217.534
# 46      835.905
# 47      271.488
# 48      12666.7
# 49         2.71
# 50      6810.61
# 51      1085.47
# 52      17.7117
# 53       5194.9
# 54            0
# 55      0.54284
# 56      436.198
# 57    0.0256386
# 58        2.337
# 59      2666.26
# 60      15962.9
# 61      5949.21
# 62       16.916
# ...

# %%
valeurs4={}

# %%
for index, name in myfile['isocode'].items():
    print(name)
    
    if name in valeurs4:
        continue
         
    time.sleep(5)
    
    if name == 'IOT':
        url= 'http://api.worldbank.org/v2/country/' + 'IND' + '/indicator/NE.CON.PRVT.PP.CD?format=json' 
    else:
        url= 'http://api.worldbank.org/v2/country/' + name + '/indicator/NE.CON.PRVT.PP.CD?format=json'
    r= requests.get(url)
    if r.status_code==200:
        data= r.json()
        compteur=0
        
        if name == 'YEM':
            valeurs4[name]='No value'
        else:
            valeurs4[name]=data[1][compteur]['value']
        while valeurs4[name] is None:
            compteur += 1
            valeurs4[name]=data[1][compteur]['value']
    
    else:
        print('[ERROR] WE CANNOT GET GET THE DATA, REASON IS', r.status_code, r.text)
        print(name)
# Out:
# AFG
# ALB
# ARM
# AZE
# BHR
# BGD
# BLR
# BTN
# BIH
# BRN
# BGR
# KHM
# CHN
# HRV
# CZE
# TLS
# EGY

# %%
valeurs4
# Out:
# {'AFG': 29.5593487980126,
#  'ALB': None,
#  'ARM': 24646011266.4461,
#  'AZE': 101816213142.578,
#  'BHR': 25891874525.3579,
#  'BGD': 468641046891.964,
#  'BLR': 127064432314.599}
